# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-odrjy4p1
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-odrjy4p1
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=07dbfc6fe4d6958c2699685a4b656273b077f94f2d909ed916e42e6ea84e1a8f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-81ls5gzt/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
# !mkdir ./sample_data

args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# mkdir: cannot create directory ‘./sample_data’: File exists
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k),torch.nn.ReLU(),torch.nn.Linear(D_k, D_k),torch.nn.ReLU(),torch.nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)



# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.582044, train error 59.47,  test loss 1.656399, test error 66.20
# Epoch     1, train loss 1.333595, train error 50.05,  test loss 1.490443, test error 58.40
# Epoch     2, train loss 1.147199, train error 41.50,  test loss 1.342083, test error 53.10
# Epoch     3, train loss 0.973370, train error 35.05,  test loss 1.202281, test error 45.80
# Epoch     4, train loss 0.851670, train error 29.25,  test loss 1.152032, test error 44.00
# Epoch     5, train loss 0.756842, train error 26.05,  test loss 1.125344, test error 43.90
# Epoch     6, train loss 0.701538, train error 24.20,  test loss 1.124479, test error 42.00
# Epoch     7, train loss 0.656904, train error 23.45,  test loss 1.111338, test error 41.80
# Epoch     8, train loss 0.572574, train error 19.65,  test loss 1.079155, test error 40.60
# Epoch     9, train loss 0.500770, train error 16.78,  test loss 1.066928, test error 40.70
# Epoch    10, train loss 0.417178, train error 12.65,  test loss 1.037740, test error 37.50
# Epoch    11, train loss 0.368652, train error 10.53,  test loss 1.028064, test error 36.20
# Epoch    12, train loss 0.338945, train error 9.55,  test loss 1.050998, test error 37.70
# Epoch    13, train loss 0.307411, train error 7.65,  test loss 1.048490, test error 37.00
# Epoch    14, train loss 0.283538, train error 7.18,  test loss 1.032454, test error 36.60
# Epoch    15, train loss 0.260922, train error 6.38,  test loss 1.045828, test error 36.40
# Epoch    16, train loss 0.243022, train error 5.88,  test loss 1.069739, test error 36.40
# Epoch    17, train loss 0.224854, train error 5.07,  test loss 1.113885, test error 36.00
# Epoch    18, train loss 0.194459, train error 3.15,  test loss 1.111957, test error 35.90
# Epoch    19, train loss 0.170865, train error 2.47,  test loss 1.111261, test error 35.90
# Epoch    20, train loss 0.146540, train error 1.55,  test loss 1.102179, test error 35.70
# Epoch    21, train loss 0.138654, train error 1.28,  test loss 1.103543, test error 34.90
# Epoch    22, train loss 0.130007, train error 1.12,  test loss 1.116219, test error 35.30
# Epoch    23, train loss 0.125219, train error 0.93,  test loss 1.131900, test error 36.10
# Epoch    24, train loss 0.117372, train error 0.85,  test loss 1.148365, test error 36.00
# Epoch    25, train loss 0.111852, train error 0.90,  test loss 1.151556, test error 34.80
# Epoch    26, train loss 0.107923, train error 0.68,  test loss 1.145908, test error 34.70
# Epoch    27, train loss 0.100965, train error 0.62,  test loss 1.172773, test error 35.40
# Epoch    28, train loss 0.096561, train error 0.68,  test loss 1.170748, test error 35.20
# Epoch    29, train loss 0.090450, train error 0.47,  test loss 1.193932, test error 35.30
# Epoch    30, train loss 0.087329, train error 0.38,  test loss 1.196671, test error 35.20
# Epoch    31, train loss 0.084751, train error 0.32,  test loss 1.192976, test error 34.80
# Epoch    32, train loss 0.082798, train error 0.28,  test loss 1.197501, test error 35.40
# Epoch    33, train loss 0.080268, train error 0.25,  test loss 1.197980, test error 34.60
# Epoch    34, train loss 0.078228, train error 0.22,  test loss 1.204926, test error 35.20
# Epoch    35, train loss 0.077329, train error 0.20,  test loss 1.206288, test error 35.50
# Epoch    36, train loss 0.074946, train error 0.12,  test loss 1.215945, test error 35.50
# Epoch    37, train loss 0.073492, train error 0.20,  test loss 1.215356, test error 35.20
# Epoch    38, train loss 0.071356, train error 0.10,  test loss 1.225775, test error 35.20
# Epoch    39, train loss 0.069742, train error 0.10,  test loss 1.229041, test error 34.90
# Epoch    40, train loss 0.068743, train error 0.10,  test loss 1.229037, test error 34.90
# Epoch    41, train loss 0.068014, train error 0.07,  test loss 1.231583, test error 35.20
# Epoch    42, train loss 0.067478, train error 0.10,  test loss 1.233431, test error 35.00
# Epoch    43, train loss 0.066603, train error 0.07,  test loss 1.236366, test error 35.20
# Epoch    44, train loss 0.065776, train error 0.10,  test loss 1.237336, test error 35.10
# Epoch    45, train loss 0.065082, train error 0.07,  test loss 1.241213, test error 35.00
# Epoch    46, train loss 0.064611, train error 0.07,  test loss 1.244071, test error 35.00
# Epoch    47, train loss 0.063668, train error 0.07,  test loss 1.246398, test error 34.90
# Epoch    48, train loss 0.063092, train error 0.07,  test loss 1.245196, test error 35.10
# Epoch    49, train loss 0.062446, train error 0.07,  test loss 1.248872, test error 34.90

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
