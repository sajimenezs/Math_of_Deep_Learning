# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-h80bnfbu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-h80bnfbu
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=bee0ea71fdc1d7fe8aa47b49d42706b3365c28ab613fd432b83df79bddb2617a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wao8oo49/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# 1. I would expect the training error to tend to zero when 50 hidden units are used.
# 2. I expect the first minima to occur around the time 30 hidden units are used.
# 3. I expect the maximum of the double descent to occur when between 50 and 100 hidden units are used.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.267267, train error 85.80,  test loss 2.262180, test error 84.65
# Epoch   100, train loss 1.909887, train error 72.53,  test loss 1.753280, test error 69.85
# Epoch   200, train loss 1.906647, train error 71.28,  test loss 1.752627, test error 69.80
# Epoch   300, train loss 1.903387, train error 71.07,  test loss 1.737093, test error 70.03
# Epoch   400, train loss 1.902567, train error 71.22,  test loss 1.736833, test error 69.47
# Epoch   500, train loss 1.903605, train error 71.55,  test loss 1.735712, test error 69.80
# Epoch   600, train loss 1.901771, train error 70.93,  test loss 1.737105, test error 69.68
# Epoch   700, train loss 1.902146, train error 70.53,  test loss 1.741909, test error 69.95
# Epoch   800, train loss 1.901969, train error 71.25,  test loss 1.739953, test error 69.62
# Epoch   900, train loss 1.902523, train error 71.78,  test loss 1.731475, test error 69.55
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302468, train error 89.07,  test loss 2.303593, test error 89.90
# Epoch   100, train loss 1.835083, train error 69.32,  test loss 1.702416, test error 66.57
# Epoch   200, train loss 1.811189, train error 66.85,  test loss 1.664609, test error 66.10
# Epoch   300, train loss 1.792466, train error 67.07,  test loss 1.638561, test error 65.72
# Epoch   400, train loss 1.782084, train error 66.03,  test loss 1.645357, test error 64.80
# Epoch   500, train loss 1.779109, train error 66.12,  test loss 1.640847, test error 64.80
# Epoch   600, train loss 1.785496, train error 67.38,  test loss 1.653366, test error 66.43
# Epoch   700, train loss 1.772923, train error 66.03,  test loss 1.633218, test error 64.95
# Epoch   800, train loss 1.772300, train error 65.12,  test loss 1.630866, test error 64.90
# Epoch   900, train loss 1.774091, train error 65.20,  test loss 1.647879, test error 65.75
# Training model with   6 hidden variables
# Epoch     0, train loss 2.256324, train error 86.45,  test loss 2.253028, test error 86.25
# Epoch   100, train loss 1.681716, train error 61.22,  test loss 1.526179, test error 58.60
# Epoch   200, train loss 1.651129, train error 60.55,  test loss 1.491658, test error 57.78
# Epoch   300, train loss 1.631009, train error 59.55,  test loss 1.459811, test error 57.03
# Epoch   400, train loss 1.613661, train error 57.58,  test loss 1.438702, test error 55.35
# Epoch   500, train loss 1.604642, train error 57.58,  test loss 1.440855, test error 56.58
# Epoch   600, train loss 1.597188, train error 57.50,  test loss 1.437830, test error 56.20
# Epoch   700, train loss 1.588373, train error 57.20,  test loss 1.432042, test error 55.65
# Epoch   800, train loss 1.591833, train error 57.30,  test loss 1.437324, test error 56.12
# Epoch   900, train loss 1.592507, train error 57.03,  test loss 1.439784, test error 55.83
# Training model with   8 hidden variables
# Epoch     0, train loss 2.132824, train error 82.55,  test loss 2.089902, test error 81.03
# Epoch   100, train loss 1.588933, train error 56.12,  test loss 1.436114, test error 53.78
# Epoch   200, train loss 1.554749, train error 54.40,  test loss 1.409151, test error 53.58
# Epoch   300, train loss 1.529580, train error 53.22,  test loss 1.412139, test error 53.25
# Epoch   400, train loss 1.527866, train error 53.17,  test loss 1.406635, test error 53.33
# Epoch   500, train loss 1.524304, train error 53.38,  test loss 1.434340, test error 53.78
# Epoch   600, train loss 1.517328, train error 52.92,  test loss 1.434724, test error 54.58
# Epoch   700, train loss 1.499752, train error 52.25,  test loss 1.419958, test error 53.15
# Epoch   800, train loss 1.483122, train error 50.75,  test loss 1.386002, test error 51.72
# Epoch   900, train loss 1.477931, train error 50.90,  test loss 1.376889, test error 51.35
# Training model with  10 hidden variables
# Epoch     0, train loss 2.268625, train error 84.28,  test loss 2.260520, test error 84.60
# Epoch   100, train loss 1.598424, train error 56.47,  test loss 1.472622, test error 57.03
# Epoch   200, train loss 1.536204, train error 55.03,  test loss 1.429568, test error 55.28
# Epoch   300, train loss 1.526832, train error 54.60,  test loss 1.440694, test error 55.50
# Epoch   400, train loss 1.511895, train error 53.80,  test loss 1.439219, test error 55.05
# Epoch   500, train loss 1.503757, train error 53.80,  test loss 1.458384, test error 54.75
# Epoch   600, train loss 1.482243, train error 52.00,  test loss 1.463653, test error 55.25
# Epoch   700, train loss 1.473163, train error 51.92,  test loss 1.445193, test error 54.72
# Epoch   800, train loss 1.463153, train error 52.10,  test loss 1.442063, test error 54.47
# Epoch   900, train loss 1.464146, train error 51.70,  test loss 1.440990, test error 54.12
# Training model with  14 hidden variables
# Epoch     0, train loss 2.191237, train error 81.30,  test loss 2.143488, test error 79.43
# Epoch   100, train loss 1.398770, train error 46.85,  test loss 1.236801, test error 46.25
# Epoch   200, train loss 1.336608, train error 43.83,  test loss 1.218258, test error 45.58
# Epoch   300, train loss 1.298967, train error 43.47,  test loss 1.243644, test error 45.90
# Epoch   400, train loss 1.283857, train error 43.03,  test loss 1.273171, test error 46.15
# Epoch   500, train loss 1.275653, train error 43.28,  test loss 1.287454, test error 47.22
# Epoch   600, train loss 1.261269, train error 42.65,  test loss 1.294901, test error 46.67
# Epoch   700, train loss 1.252347, train error 42.12,  test loss 1.304252, test error 47.42
# Epoch   800, train loss 1.247399, train error 42.03,  test loss 1.320135, test error 48.08
# Epoch   900, train loss 1.242358, train error 41.83,  test loss 1.332304, test error 47.53
# Training model with  18 hidden variables
# Epoch     0, train loss 2.179214, train error 80.55,  test loss 2.163902, test error 80.85
# Epoch   100, train loss 1.357589, train error 44.92,  test loss 1.324555, test error 49.85
# Epoch   200, train loss 1.252480, train error 40.80,  test loss 1.336529, test error 49.67
# Epoch   300, train loss 1.200215, train error 39.88,  test loss 1.383374, test error 49.92
# Epoch   400, train loss 1.167109, train error 38.92,  test loss 1.440232, test error 50.55
# Epoch   500, train loss 1.144498, train error 38.72,  test loss 1.479708, test error 51.22
# Epoch   600, train loss 1.121835, train error 38.00,  test loss 1.503126, test error 51.38
# Epoch   700, train loss 1.120151, train error 38.00,  test loss 1.543830, test error 51.45
# Epoch   800, train loss 1.105421, train error 38.00,  test loss 1.561895, test error 52.05
# Epoch   900, train loss 1.089747, train error 37.42,  test loss 1.587204, test error 51.92
# Training model with  22 hidden variables
# Epoch     0, train loss 2.246750, train error 81.65,  test loss 2.267284, test error 82.80
# Epoch   100, train loss 1.284889, train error 42.62,  test loss 1.308278, test error 49.92
# Epoch   200, train loss 1.180520, train error 39.95,  test loss 1.371306, test error 50.28
# Epoch   300, train loss 1.116988, train error 37.45,  test loss 1.410355, test error 50.62
# Epoch   400, train loss 1.094508, train error 36.42,  test loss 1.473911, test error 51.40
# Epoch   500, train loss 1.062959, train error 35.78,  test loss 1.526221, test error 52.03
# Epoch   600, train loss 1.046798, train error 35.03,  test loss 1.583657, test error 52.58
# Epoch   700, train loss 1.032669, train error 34.57,  test loss 1.635159, test error 53.38
# Epoch   800, train loss 1.033610, train error 34.20,  test loss 1.674409, test error 52.90
# Epoch   900, train loss 1.034129, train error 34.32,  test loss 1.706100, test error 52.83
# Training model with  26 hidden variables
# Epoch     0, train loss 2.144371, train error 78.65,  test loss 2.091501, test error 77.22
# Epoch   100, train loss 1.183367, train error 39.38,  test loss 1.294280, test error 48.25
# Epoch   200, train loss 1.034635, train error 34.53,  test loss 1.404610, test error 49.90
# Epoch   300, train loss 0.940674, train error 31.07,  test loss 1.523884, test error 50.78
# Epoch   400, train loss 0.918070, train error 30.25,  test loss 1.651157, test error 51.15
# Epoch   500, train loss 0.885848, train error 29.60,  test loss 1.725534, test error 51.30
# Epoch   600, train loss 0.860429, train error 28.43,  test loss 1.781885, test error 51.33
# Epoch   700, train loss 0.840864, train error 28.28,  test loss 1.832866, test error 51.47
# Epoch   800, train loss 0.827962, train error 28.60,  test loss 1.892787, test error 51.42
# Epoch   900, train loss 0.823859, train error 28.00,  test loss 1.980531, test error 52.05
# Training model with  30 hidden variables
# Epoch     0, train loss 2.170229, train error 81.15,  test loss 2.133326, test error 80.15
# Epoch   100, train loss 1.148218, train error 37.67,  test loss 1.356952, test error 49.22
# Epoch   200, train loss 0.947900, train error 31.93,  test loss 1.540877, test error 51.90
# Epoch   300, train loss 0.865497, train error 28.62,  test loss 1.703796, test error 51.90
# Epoch   400, train loss 0.817683, train error 27.55,  test loss 1.834730, test error 53.17
# Epoch   500, train loss 0.776704, train error 26.07,  test loss 1.982432, test error 53.45
# Epoch   600, train loss 0.746164, train error 25.03,  test loss 2.112643, test error 53.45
# Epoch   700, train loss 0.708080, train error 23.50,  test loss 2.261349, test error 54.15
# Epoch   800, train loss 0.689235, train error 22.57,  test loss 2.420483, test error 54.72
# Epoch   900, train loss 0.668996, train error 22.62,  test loss 2.512943, test error 55.20
# Training model with  35 hidden variables
# Epoch     0, train loss 2.154199, train error 80.43,  test loss 2.112668, test error 80.07
# Epoch   100, train loss 0.976753, train error 30.85,  test loss 1.348601, test error 48.03
# Epoch   200, train loss 0.764783, train error 24.68,  test loss 1.650792, test error 48.97
# Epoch   300, train loss 0.631582, train error 20.80,  test loss 1.992616, test error 51.35
# Epoch   400, train loss 0.601893, train error 20.32,  test loss 2.311235, test error 53.33
# Epoch   500, train loss 0.508893, train error 17.22,  test loss 2.623043, test error 53.25
# Epoch   600, train loss 0.485267, train error 16.40,  test loss 3.016599, test error 54.22
# Epoch   700, train loss 0.468745, train error 15.93,  test loss 3.324439, test error 54.83
# Epoch   800, train loss 0.418998, train error 13.75,  test loss 3.544317, test error 55.25
# Epoch   900, train loss 0.463969, train error 16.05,  test loss 3.831288, test error 56.20
# Training model with  40 hidden variables
# Epoch     0, train loss 2.078624, train error 76.38,  test loss 2.044358, test error 75.62
# Epoch   100, train loss 0.926361, train error 29.93,  test loss 1.459048, test error 50.28
# Epoch   200, train loss 0.666475, train error 22.12,  test loss 1.972470, test error 52.80
# Epoch   300, train loss 0.492966, train error 16.45,  test loss 2.525004, test error 54.72
# Epoch   400, train loss 0.478517, train error 16.95,  test loss 3.290673, test error 56.88
# Epoch   500, train loss 0.359952, train error 12.45,  test loss 3.868472, test error 56.15
# Epoch   600, train loss 0.361904, train error 13.20,  test loss 4.583578, test error 57.53
# Epoch   700, train loss 0.296053, train error 10.53,  test loss 5.169372, test error 57.38
# Epoch   800, train loss 0.252951, train error 8.97,  test loss 5.770392, test error 58.35
# Epoch   900, train loss 0.319215, train error 11.85,  test loss 6.350403, test error 59.00
# Training model with  45 hidden variables
# Epoch     0, train loss 2.136116, train error 79.03,  test loss 2.114229, test error 78.20
# Epoch   100, train loss 0.837635, train error 27.05,  test loss 1.468672, test error 50.40
# Epoch   200, train loss 0.478259, train error 14.72,  test loss 2.223498, test error 53.03
# Epoch   300, train loss 0.316022, train error 10.62,  test loss 3.320142, test error 55.30
# Epoch   400, train loss 0.233610, train error 7.85,  test loss 4.600471, test error 54.62
# Epoch   500, train loss 0.169334, train error 6.05,  test loss 5.958363, test error 55.58
# Epoch   600, train loss 0.116137, train error 3.45,  test loss 7.101597, test error 55.67
# Epoch   700, train loss 0.013452, train error 0.00,  test loss 8.187682, test error 56.85
# Epoch   800, train loss 0.008773, train error 0.00,  test loss 8.862326, test error 57.22
# Epoch   900, train loss 0.006434, train error 0.00,  test loss 9.379004, test error 57.22
# Training model with  50 hidden variables
# Epoch     0, train loss 2.112937, train error 78.12,  test loss 2.078472, test error 77.78
# Epoch   100, train loss 0.721084, train error 22.62,  test loss 1.525215, test error 49.72
# Epoch   200, train loss 0.342692, train error 10.28,  test loss 2.491299, test error 53.38
# Epoch   300, train loss 0.139290, train error 3.15,  test loss 4.162020, test error 55.45
# Epoch   400, train loss 0.027293, train error 0.00,  test loss 5.703099, test error 56.05
# Epoch   500, train loss 0.012917, train error 0.00,  test loss 6.653572, test error 56.17
# Epoch   600, train loss 0.008218, train error 0.00,  test loss 7.265363, test error 56.12
# Epoch   700, train loss 0.005858, train error 0.00,  test loss 7.737877, test error 56.38
# Epoch   800, train loss 0.004534, train error 0.00,  test loss 8.115482, test error 56.67
# Epoch   900, train loss 0.003686, train error 0.00,  test loss 8.429389, test error 56.50
# Training model with  55 hidden variables
# Epoch     0, train loss 2.071579, train error 76.97,  test loss 2.020199, test error 76.85
# Epoch   100, train loss 0.592335, train error 18.32,  test loss 1.670329, test error 49.72
# Epoch   200, train loss 0.171920, train error 3.72,  test loss 3.196655, test error 53.88
# Epoch   300, train loss 0.027730, train error 0.00,  test loss 4.819582, test error 53.80
# Epoch   400, train loss 0.011734, train error 0.00,  test loss 5.717298, test error 53.92
# Epoch   500, train loss 0.007121, train error 0.00,  test loss 6.272234, test error 54.28
# Epoch   600, train loss 0.005038, train error 0.00,  test loss 6.675189, test error 54.35
# Epoch   700, train loss 0.003821, train error 0.00,  test loss 6.988805, test error 54.30
# Epoch   800, train loss 0.003047, train error 0.00,  test loss 7.257898, test error 54.47
# Epoch   900, train loss 0.002515, train error 0.00,  test loss 7.483808, test error 54.55
# Training model with  60 hidden variables
# Epoch     0, train loss 2.055848, train error 76.60,  test loss 1.971586, test error 75.20
# Epoch   100, train loss 0.530345, train error 15.03,  test loss 1.740575, test error 51.28
# Epoch   200, train loss 0.110745, train error 0.90,  test loss 3.353911, test error 53.67
# Epoch   300, train loss 0.020681, train error 0.00,  test loss 4.764434, test error 54.88
# Epoch   400, train loss 0.009632, train error 0.00,  test loss 5.457660, test error 54.80
# Epoch   500, train loss 0.006053, train error 0.00,  test loss 5.916195, test error 55.22
# Epoch   600, train loss 0.004304, train error 0.00,  test loss 6.245795, test error 55.20
# Epoch   700, train loss 0.003303, train error 0.00,  test loss 6.512802, test error 55.03
# Epoch   800, train loss 0.002671, train error 0.00,  test loss 6.737710, test error 55.03
# Epoch   900, train loss 0.002207, train error 0.00,  test loss 6.926705, test error 55.10
# Training model with  70 hidden variables
# Epoch     0, train loss 2.028078, train error 75.70,  test loss 1.957146, test error 75.12
# Epoch   100, train loss 0.395931, train error 10.68,  test loss 1.939463, test error 52.70
# Epoch   200, train loss 0.038950, train error 0.00,  test loss 3.569392, test error 53.72
# Epoch   300, train loss 0.012197, train error 0.00,  test loss 4.412813, test error 53.62
# Epoch   400, train loss 0.006574, train error 0.00,  test loss 4.892634, test error 53.60
# Epoch   500, train loss 0.004365, train error 0.00,  test loss 5.215166, test error 53.75
# Epoch   600, train loss 0.003197, train error 0.00,  test loss 5.460168, test error 53.95
# Epoch   700, train loss 0.002498, train error 0.00,  test loss 5.659350, test error 54.05
# Epoch   800, train loss 0.002033, train error 0.00,  test loss 5.823345, test error 54.15
# Epoch   900, train loss 0.001701, train error 0.00,  test loss 5.963319, test error 54.12
# Training model with  80 hidden variables
# Epoch     0, train loss 1.986313, train error 73.60,  test loss 1.920665, test error 74.03
# Epoch   100, train loss 0.219679, train error 3.60,  test loss 2.147189, test error 51.50
# Epoch   200, train loss 0.019034, train error 0.00,  test loss 3.497280, test error 53.35
# Epoch   300, train loss 0.007660, train error 0.00,  test loss 4.049978, test error 53.30
# Epoch   400, train loss 0.004584, train error 0.00,  test loss 4.383273, test error 53.25
# Epoch   500, train loss 0.003184, train error 0.00,  test loss 4.624061, test error 53.35
# Epoch   600, train loss 0.002399, train error 0.00,  test loss 4.808672, test error 53.25
# Epoch   700, train loss 0.001909, train error 0.00,  test loss 4.960867, test error 53.47
# Epoch   800, train loss 0.001574, train error 0.00,  test loss 5.089446, test error 53.35
# Epoch   900, train loss 0.001334, train error 0.00,  test loss 5.199375, test error 53.22
# Training model with  90 hidden variables
# Epoch     0, train loss 2.074686, train error 76.45,  test loss 2.034928, test error 76.72
# Epoch   100, train loss 0.131803, train error 0.80,  test loss 2.188574, test error 50.88
# Epoch   200, train loss 0.014659, train error 0.00,  test loss 3.135088, test error 50.90
# Epoch   300, train loss 0.006520, train error 0.00,  test loss 3.547357, test error 51.12
# Epoch   400, train loss 0.003989, train error 0.00,  test loss 3.804034, test error 51.17
# Epoch   500, train loss 0.002815, train error 0.00,  test loss 3.988345, test error 51.15
# Epoch   600, train loss 0.002142, train error 0.00,  test loss 4.131706, test error 50.90
# Epoch   700, train loss 0.001713, train error 0.00,  test loss 4.247896, test error 50.88
# Epoch   800, train loss 0.001418, train error 0.00,  test loss 4.346694, test error 51.05
# Epoch   900, train loss 0.001204, train error 0.00,  test loss 4.432626, test error 51.08
# Training model with 100 hidden variables
# Epoch     0, train loss 1.989470, train error 74.35,  test loss 1.924764, test error 73.45
# Epoch   100, train loss 0.096783, train error 0.30,  test loss 2.186324, test error 49.70
# Epoch   200, train loss 0.012248, train error 0.00,  test loss 3.027215, test error 50.15
# Epoch   300, train loss 0.005678, train error 0.00,  test loss 3.374060, test error 50.38
# Epoch   400, train loss 0.003547, train error 0.00,  test loss 3.595105, test error 50.40
# Epoch   500, train loss 0.002517, train error 0.00,  test loss 3.757991, test error 50.58
# Epoch   600, train loss 0.001930, train error 0.00,  test loss 3.884190, test error 50.50
# Epoch   700, train loss 0.001549, train error 0.00,  test loss 3.989844, test error 50.53
# Epoch   800, train loss 0.001287, train error 0.00,  test loss 4.077685, test error 50.53
# Epoch   900, train loss 0.001096, train error 0.00,  test loss 4.155759, test error 50.53
# Training model with 120 hidden variables
# Epoch     0, train loss 1.954722, train error 73.43,  test loss 1.894346, test error 74.25
# Epoch   100, train loss 0.044984, train error 0.00,  test loss 2.129619, test error 49.15
# Epoch   200, train loss 0.009090, train error 0.00,  test loss 2.681833, test error 49.17
# Epoch   300, train loss 0.004556, train error 0.00,  test loss 2.934917, test error 49.22
# Epoch   400, train loss 0.002936, train error 0.00,  test loss 3.101213, test error 49.10
# Epoch   500, train loss 0.002122, train error 0.00,  test loss 3.223652, test error 49.20
# Epoch   600, train loss 0.001643, train error 0.00,  test loss 3.321054, test error 49.05
# Epoch   700, train loss 0.001330, train error 0.00,  test loss 3.402539, test error 48.97
# Epoch   800, train loss 0.001112, train error 0.00,  test loss 3.471667, test error 49.05
# Epoch   900, train loss 0.000951, train error 0.00,  test loss 3.532433, test error 49.05
# Training model with 140 hidden variables
# Epoch     0, train loss 1.950091, train error 70.93,  test loss 1.887928, test error 72.60
# Epoch   100, train loss 0.036995, train error 0.00,  test loss 2.075542, test error 48.65
# Epoch   200, train loss 0.008093, train error 0.00,  test loss 2.543125, test error 48.30
# Epoch   300, train loss 0.004139, train error 0.00,  test loss 2.766570, test error 48.30
# Epoch   400, train loss 0.002683, train error 0.00,  test loss 2.911163, test error 48.30
# Epoch   500, train loss 0.001953, train error 0.00,  test loss 3.020062, test error 48.20
# Epoch   600, train loss 0.001517, train error 0.00,  test loss 3.106637, test error 48.15
# Epoch   700, train loss 0.001231, train error 0.00,  test loss 3.178750, test error 48.17
# Epoch   800, train loss 0.001031, train error 0.00,  test loss 3.239948, test error 48.22
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.293066, test error 48.15
# Training model with 160 hidden variables
# Epoch     0, train loss 1.909555, train error 69.82,  test loss 1.829880, test error 71.50
# Epoch   100, train loss 0.027308, train error 0.00,  test loss 2.105257, test error 48.97
# Epoch   200, train loss 0.007070, train error 0.00,  test loss 2.498239, test error 49.62
# Epoch   300, train loss 0.003752, train error 0.00,  test loss 2.691416, test error 49.78
# Epoch   400, train loss 0.002464, train error 0.00,  test loss 2.818876, test error 49.80
# Epoch   500, train loss 0.001807, train error 0.00,  test loss 2.916880, test error 49.83
# Epoch   600, train loss 0.001412, train error 0.00,  test loss 2.993182, test error 49.70
# Epoch   700, train loss 0.001151, train error 0.00,  test loss 3.057900, test error 49.85
# Epoch   800, train loss 0.000967, train error 0.00,  test loss 3.112758, test error 49.78
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.161264, test error 49.80
# Training model with 180 hidden variables
# Epoch     0, train loss 1.911339, train error 69.97,  test loss 1.823978, test error 70.38
# Epoch   100, train loss 0.026070, train error 0.00,  test loss 2.074459, test error 48.90
# Epoch   200, train loss 0.006855, train error 0.00,  test loss 2.452534, test error 48.95
# Epoch   300, train loss 0.003639, train error 0.00,  test loss 2.639069, test error 49.00
# Epoch   400, train loss 0.002399, train error 0.00,  test loss 2.763561, test error 49.12
# Epoch   500, train loss 0.001760, train error 0.00,  test loss 2.857821, test error 49.33
# Epoch   600, train loss 0.001377, train error 0.00,  test loss 2.932757, test error 49.28
# Epoch   700, train loss 0.001123, train error 0.00,  test loss 2.995877, test error 49.35
# Epoch   800, train loss 0.000943, train error 0.00,  test loss 3.049524, test error 49.22
# Epoch   900, train loss 0.000810, train error 0.00,  test loss 3.096767, test error 49.22
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926490, train error 69.75,  test loss 1.846408, test error 71.62
# Epoch   100, train loss 0.021609, train error 0.00,  test loss 2.032039, test error 48.38
# Epoch   200, train loss 0.006108, train error 0.00,  test loss 2.354341, test error 48.55
# Epoch   300, train loss 0.003311, train error 0.00,  test loss 2.517335, test error 48.30
# Epoch   400, train loss 0.002204, train error 0.00,  test loss 2.624953, test error 48.15
# Epoch   500, train loss 0.001626, train error 0.00,  test loss 2.706136, test error 48.20
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.771992, test error 48.15
# Epoch   700, train loss 0.001044, train error 0.00,  test loss 2.826179, test error 48.15
# Epoch   800, train loss 0.000879, train error 0.00,  test loss 2.873617, test error 48.20
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.914203, test error 48.12
# Training model with 250 hidden variables
# Epoch     0, train loss 1.920511, train error 70.07,  test loss 1.841471, test error 70.93
# Epoch   100, train loss 0.016468, train error 0.00,  test loss 1.915467, test error 47.92
# Epoch   200, train loss 0.005236, train error 0.00,  test loss 2.166842, test error 47.78
# Epoch   300, train loss 0.002924, train error 0.00,  test loss 2.299154, test error 47.60
# Epoch   400, train loss 0.001977, train error 0.00,  test loss 2.390975, test error 47.58
# Epoch   500, train loss 0.001474, train error 0.00,  test loss 2.460714, test error 47.62
# Epoch   600, train loss 0.001164, train error 0.00,  test loss 2.516578, test error 47.58
# Epoch   700, train loss 0.000956, train error 0.00,  test loss 2.563062, test error 47.65
# Epoch   800, train loss 0.000808, train error 0.00,  test loss 2.603923, test error 47.67
# Epoch   900, train loss 0.000697, train error 0.00,  test loss 2.639312, test error 47.67
# Training model with 300 hidden variables
# Epoch     0, train loss 1.862786, train error 67.07,  test loss 1.793078, test error 69.68
# Epoch   100, train loss 0.014863, train error 0.00,  test loss 1.823082, test error 45.65
# Epoch   200, train loss 0.004935, train error 0.00,  test loss 2.038192, test error 45.55
# Epoch   300, train loss 0.002797, train error 0.00,  test loss 2.152793, test error 45.25
# Epoch   400, train loss 0.001899, train error 0.00,  test loss 2.231901, test error 45.47
# Epoch   500, train loss 0.001421, train error 0.00,  test loss 2.292362, test error 45.35
# Epoch   600, train loss 0.001125, train error 0.00,  test loss 2.341209, test error 45.33
# Epoch   700, train loss 0.000926, train error 0.00,  test loss 2.382786, test error 45.47
# Epoch   800, train loss 0.000783, train error 0.00,  test loss 2.418875, test error 45.53
# Epoch   900, train loss 0.000676, train error 0.00,  test loss 2.450311, test error 45.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.875673, train error 67.65,  test loss 1.836474, test error 70.78
# Epoch   100, train loss 0.011578, train error 0.00,  test loss 1.793895, test error 46.67
# Epoch   200, train loss 0.004130, train error 0.00,  test loss 1.971186, test error 46.62
# Epoch   300, train loss 0.002393, train error 0.00,  test loss 2.070807, test error 46.42
# Epoch   400, train loss 0.001649, train error 0.00,  test loss 2.139414, test error 46.40
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.192204, test error 46.38
# Epoch   600, train loss 0.000990, train error 0.00,  test loss 2.235389, test error 46.38
# Epoch   700, train loss 0.000818, train error 0.00,  test loss 2.271217, test error 46.38
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.302446, test error 46.42
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.329792, test error 46.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
